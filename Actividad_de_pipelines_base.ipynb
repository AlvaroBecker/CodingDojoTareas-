# %% [markdown]
# <a href="https://colab.research.google.com/github/AlvaroBecker/CodingDojoTareas-/blob/main/Actividad_de_pipelines_base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def format_drive_url(url):
    file_id = url.split('/')[-2]
    download_url = f'https://drive.google.com/uc?id={file_id}&export=download'
    return download_url

url='https://docs.google.com/spreadsheets/d/1LilOd-okRO6DCQ6nSBWMTEhW_UlqTcWr/edit?usp=sharing&ouid=106773039522351372029&rtpof=true&sd=true'
import pandas as pd
df=pd.read_excel(format_drive_url(url))

# %%
df
# Out:
#                        name                 Manufacturer  type  \
# 0   Apple Cinnamon Cheerios                General Mills  Cold
# 1                   Basic 4                General Mills  Cold
# 2                  Cheerios                General Mills  Cold
# 3     Cinnamon Toast Crunch                General Mills  Cold
# 4                  Clusters                General Mills  Cold
# ..                      ...                          ...   ...
# 72                Rice Chex               Ralston Purina  Cold
# 73               Wheat Chex               Ralston Purina  Cold
# 74                    Maypo  American Home Food Products   Hot
# 75   Cream of Wheat (Quick)                      Nabisco   Hot
# 76           Quaker Oatmeal                  Quaker Oats   Hot
#
#     calories per serving  grams of protein  grams of fat  \
# 0                  110.0                 2           2.0
# 1                  130.0                 3           2.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   name                                             77 non-null     object
#  1   Manufacturer                                     77 non-null     object
#  2   type                                             68 non-null     object
#  3   calories per serving                             70 non-null     float64
#  4   grams of protein                                 77 non-null     int64
#  5   grams of fat                                     69 non-null     float64
#  6   milligrams of sodium                             76 non-null     float64
#  7   grams of dietary fiber                           77 non-null     float64
#  8   grams of complex carbohydrates                   77 non-null     float64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Manufacturer,type,grams of fat, grams of sugars,Weight in ounces per one serving

# %%
df=df[['calories per serving','Manufacturer','type','grams of fat', 'grams of sugars','Weight in ounces per one serving']]
df
# Out:
#     calories per serving                 Manufacturer  type  grams of fat  \
# 0                  110.0                General Mills  Cold           2.0
# 1                  130.0                General Mills  Cold           2.0
# 2                    NaN                General Mills  Cold           2.0
# 3                  120.0                General Mills  Cold           3.0
# 4                  110.0                General Mills  Cold           2.0
# ..                   ...                          ...   ...           ...
# 72                 110.0               Ralston Purina  Cold           NaN
# 73                 100.0               Ralston Purina  Cold           1.0
# 74                 100.0  American Home Food Products   Hot           1.0
# 75                 100.0                      Nabisco   Hot           0.0
# 76                 100.0                  Quaker Oats   Hot           2.0
#
#     grams of sugars  Weight in ounces per one serving
# ...

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# calories per serving                 9.090909
# Manufacturer                         0.000000
# type                                11.688312
# grams of fat                        10.389610
# grams of sugars                     11.688312
# Weight in ounces per one serving     0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 5

# %%
df.loc[df.duplicated()]
# Out:
#     calories per serving   Manufacturer  type  grams of fat  grams of sugars  \
# 15                 110.0  General Mills  Cold           1.0              3.0
# 18                 110.0  General Mills  Cold           1.0              3.0
# 39                   NaN       Kelloggs  Cold           0.0              3.0
# 48                  90.0        Nabisco  Cold           0.0              0.0
# 64                  50.0    Quaker Oats  Cold           0.0              0.0
#
#     Weight in ounces per one serving
# 15                               1.0
# 18                               1.0
# 39                               1.0
# 48                               1.0
# 64                               0.5

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_selector
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
import numpy as np
y=df['calories per serving']
X=df.drop(columns=['calories per serving'])

X_train, X_test, y_train, y_test= train_test_split(X,y,random_state=42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   calories per serving              70 non-null     float64
#  1   Manufacturer                      77 non-null     object
#  2   type                              68 non-null     object
#  3   grams of fat                      69 non-null     float64
#  4   grams of sugars                   68 non-null     float64
#  5   Weight in ounces per one serving  77 non-null     float64
# dtypes: float64(4), object(2)
# memory usage: 3.7+ KB

# %% [markdown]
#     calories per serving: numerica
#     Manufacturer:nominal
#     type:nominal
#     grams of fat:numerica
#     grams of sugars:numerica
#     Weight in ounces per one serving:numerica

# %%
cat_selector = make_column_selector(dtype_include='object')
cat_columns=X_train[cat_selector(X_train)]
numeric_selector=make_column_selector(dtype_include='number')
num_columns=X_train[numeric_selector(X_train)]

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn import set_config
set_config(display='diagram')
num_transformer = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler())
cat_transformer = make_pipeline(
    SimpleImputer(strategy='most_frequent'),
    OneHotEncoder(handle_unknown='ignore'))

# %%
preprocessor = make_column_transformer(
    (num_transformer, make_column_selector(dtype_include=np.number)),
    (cat_transformer, make_column_selector(dtype_exclude=np.number))
)

# %%
pipeline = make_pipeline(preprocessor)
pipeline.fit(X_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7f02aba3e9a0>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
# ...

# %%
X_train_processed= pipeline.transform(X_train)
X_test_processed= pipeline.transform(X_test)

# %%
print(np.isnan(X_train_processed).sum().sum(), 'missing values in training data')
print(np.isnan(X_test_processed).sum().sum(), 'missing values in testing data')
# Out:
# 0 missing values in training data
# 0 missing values in testing data

# %%
X_train_processed
# Out:
# array([[-9.74679434e-01,  9.94481647e-01, -1.32764897e-01,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  1.22191915e+00,  2.03880702e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00],
#        [-9.74679434e-01, -8.25018407e-01, -1.32764897e-01,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  1.67679417e+00,  3.15749558e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00, -1.42705887e-01, -1.32764897e-01,
# ...

# %%
X_test_processed
# Out:
# array([[ 9.74679434e-01,  8.47316202e-02, -1.32764897e-01,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00],
#        [ 9.74679434e-01,  1.44935666e+00,  3.15749558e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00, -8.25018407e-01, -1.32764897e-01,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00],
#        [ 9.74679434e-01,  7.67044141e-01, -1.32764897e-01,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00, -1.42705887e-01, -1.32764897e-01,
# ...
